# %% [markdown]
# <a href="https://colab.research.google.com/github/theBuluku/Financial_Research-/blob/master/Moringa_Data_Science_Core_W1_Independent_Project_2018_08_Malcolm_Buluku.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ANALYSIS OF THE FINANICIAL STATE IN TERMS OF CREDIT IN KENYAN HOUSE HOLDS

# %%
# Importing Pandas
# 
import pandas as pd

# %%
# Importing Numpy
#
import numpy as np

# %%
# Importing Seaborn
#
import seaborn as sns

# %%
# Importing Matplotlib
#
import matplotlib.pyplot as plt

# %%
#Loading my dataset for analysis
url='http://bit.ly/FinancialDataset'
financial_df= pd.read_csv('http://bit.ly/FinancialDataset')
financial_df.head(10)
# Out:
#   country  year  ...              Level of Educuation                   Type of Job
# 0   Kenya  2018  ...              Secondary education                 Self employed
# 1   Kenya  2018  ...              No formal education          Government Dependent
# 2   Kenya  2018  ...  Vocational/Specialised training                 Self employed
# 3   Kenya  2018  ...                Primary education     Formally employed Private
# 4   Kenya  2018  ...                Primary education           Informally employed
# 5   Kenya  2018  ...                Primary education           Informally employed
# 6   Kenya  2018  ...                Primary education                 Self employed
# 7   Kenya  2018  ...               Tertiary education  Formally employed Government
# 8   Kenya  2018  ...              Secondary education           Farming and Fishing
# 9   Kenya  2018  ...              No formal education          Remittance Dependent
#
# [10 rows x 13 columns]

# %%
#gives information about the dataset.
financial_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
# country                   23510 non-null object
# year                      23524 non-null int64
# uniqueid                  23524 non-null object
# Has a Bank account        23488 non-null object
# Type of Location          23509 non-null object
# Cell Phone Access         23513 non-null object
# household_size            23496 non-null float64
# Respondent Age            23490 non-null float64
# gender_of_respondent      23490 non-null object
# The relathip with head    23520 non-null object
# marital_status            23492 non-null object
# Level of Educuation       23495 non-null object
# Type of Job               23494 non-null object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.3+ MB

# %%
#The describe function returns a pandas series type that provides descriptive statistics which summarize
#the central tendency, dispersion, and shape of a dataset’s distribution, excluding NaN values.
financial_df.describe()
# Out:
#                year  household_size  Respondent Age
# count  23524.000000    23496.000000    23490.000000
# mean    2016.979000        3.681818       38.804300
# std        0.899669        2.279933       16.519996
# min     2016.000000        0.000000       16.000000
# 25%     2016.000000        2.000000       26.000000
# 50%     2017.000000        3.000000       35.000000
# 75%     2018.000000        5.000000       49.000000
# max     2056.000000       21.000000      100.000000

# %%
financial_df.describe(include='all')
# Out:
#        country          year  ... Level of Educuation    Type of Job
# count    23510  23524.000000  ...               23495          23494
# unique       4           NaN  ...                   7             10
# top     Rwanda           NaN  ...   Primary education  Self employed
# freq      8735           NaN  ...               12775           6428
# mean       NaN   2016.979000  ...                 NaN            NaN
# std        NaN      0.899669  ...                 NaN            NaN
# min        NaN   2016.000000  ...                 NaN            NaN
# 25%        NaN   2016.000000  ...                 NaN            NaN
# 50%        NaN   2017.000000  ...                 NaN            NaN
# 75%        NaN   2018.000000  ...                 NaN            NaN
# max        NaN   2056.000000  ...                 NaN            NaN
#
# [11 rows x 13 columns]

# %%
financial_df.columns
# Out:
# Index(['country', 'year', 'uniqueid', 'Has a Bank account', 'Type of Location',
#        'Cell Phone Access', 'household_size', 'Respondent Age',
#        'gender_of_respondent', 'The relathip with head', 'marital_status',
#        'Level of Educuation', 'Type of Job'],
#       dtype='object')

# %%
sns.pairplot(financial_df)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
#gives the number of rows and columns
print(financial_df.shape)
# Out:
# (23524, 13)

# %%
print(financial_df.nunique())
# Out:
# country                      4
# year                         6
# uniqueid                  8735
# Has a Bank account           2
# Type of Location             2
# Cell Phone Access            2
# household_size              21
# Respondent Age              85
# gender_of_respondent         2
# The relathip with head       6
# marital_status               5
# Level of Educuation          7
# Type of Job                 10
# dtype: int64

# %% [markdown]
# Cleaning  Data for Analysis.

# %%
#Renaming columns for easier understanding of data.
financial_df.rename(columns={'country':'Country','uniqueid':'Unique_Id', 'gender_of_respondent': 'Gender','Type of Job':'Job_Type','year':'Year','Respondent Age':'Age','marital_status':'Marital_Status','household_size':'Household_Size'})
financial_df.head()
# Out:
#   country  year  ...              Level of Educuation                Type of Job
# 0   Kenya  2018  ...              Secondary education              Self employed
# 1   Kenya  2018  ...              No formal education       Government Dependent
# 2   Kenya  2018  ...  Vocational/Specialised training              Self employed
# 3   Kenya  2018  ...                Primary education  Formally employed Private
# 4   Kenya  2018  ...                Primary education        Informally employed
#
# [5 rows x 13 columns]

# %%
#Dropping unnecessary columns
financial_df.drop(["uniqueid", "The relathip with head"], axis = 1, inplace = True)

# %%
financial_df.head()
# Out:
#   country  year  ...              Level of Educuation                Type of Job
# 0   Kenya  2018  ...              Secondary education              Self employed
# 1   Kenya  2018  ...              No formal education       Government Dependent
# 2   Kenya  2018  ...  Vocational/Specialised training              Self employed
# 3   Kenya  2018  ...                Primary education  Formally employed Private
# 4   Kenya  2018  ...                Primary education        Informally employed
#
# [5 rows x 11 columns]

# %%
#Checking for null values and filling the null values with mean
financial_df.fillna(financial_df.mean())
# Out:
#       country  ...                   Type of Job
# 0       Kenya  ...                 Self employed
# 1       Kenya  ...          Government Dependent
# 2       Kenya  ...                 Self employed
# 3       Kenya  ...     Formally employed Private
# 4       Kenya  ...           Informally employed
# 5       Kenya  ...           Informally employed
# 6       Kenya  ...                 Self employed
# 7       Kenya  ...  Formally employed Government
# 8       Kenya  ...           Farming and Fishing
# 9       Kenya  ...          Remittance Dependent
# 10      Kenya  ...           Farming and Fishing
# 11      Kenya  ...                  Other Income
# 12      Kenya  ...           Farming and Fishing
# 13      Kenya  ...                 Self employed
# 14      Kenya  ...           Informally employed
# 15      Kenya  ...           Informally employed
# 16      Kenya  ...                 Self employed
# 17      Kenya  ...                 Self employed
# ...

# %% [markdown]
# Linear Regression.

# %%
#checking for the distribution of the respondent's age
sns.distplot(financial_df['household_size'])

# %%
#Shows us correlation between all the columns in our dataset
financial_df.corr()
# Out:
#                     year  household_size  Respondent Age
# year            1.000000       -0.049344       -0.019570
# household_size -0.049344        1.000000       -0.119709
# Respondent Age -0.019570       -0.119709        1.000000

# %%
sns.heatmap(financial_df.corr(), annot=True)

# %%
financial_df.columns
# Out:
# Index(['country', 'year', 'Has a Bank account', 'Type of Location',
#        'Cell Phone Access', 'household_size', 'Respondent Age',
#        'gender_of_respondent', 'marital_status', 'Level of Educuation',
#        'Type of Job'],
#       dtype='object')

# %%
x=financial_df[['country', 'year', 'Has a Bank account', 'Type of Location',
       'Cell Phone Access', 'household_size', 'Respondent Age',
       'gender_of_respondent', 'marital_status', 'Level of Educuation',
       'Type of Job']]

# %%
y=financial_df['Age']

# %% [markdown]
# Principle Component Analysis.

# %% [markdown]
# Principal component analysis (PCA) is a statistical procedure that uses an orthogonal transformation to convert a set of observations of possibly correlated variables (entities each of which takes on various numerical values) into a set of values of linearly uncorrelated variables called principal components.

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

#displaying scatter plot matrix
scatter_matrix(financial_df)
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn import preprocessing

# %%
#Perform PCA
pca=PCA(n_components=2)
pc=pca.fit_transform(financial_df)

#Print new dimensions
print(pc.shape)
print (pc[:10])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-a801da2a21da> in <module>()
#       1 pca=PCA(n_components=2)
# ----> 2 pc=pca.fit_transform(financial_df)
#       3
#       4 #Print new dimensions
#       5 print(pc.shape)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/pca.py in fit_transform(self, X, y)
#     358
#     359         """
# --> 360         U, S, V = self._fit(X)
#     361         U = U[:, :self.n_components_]
#     362
#
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/pca.py in _fit(self, X)
#     380
#     381         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 382                         copy=self.copy)
#     383
#     384         # Handle n_components==None
#
# ...
